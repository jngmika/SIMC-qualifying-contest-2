# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1
#
# ###  Build a criterion that, with the best possible accuracy, differentiates lizards of species #5 from all other lizards and uses only the femoral pore number on the right side (FPNr).
# ### *Hint: plot and explore the FPNr distribution of the lizards with regard to their species.*

# %%
df = pd.read_csv("lizards_data.csv")

# %%
df[["Species_num", "FPNr"]]
# Out:
#      Species_num  FPNr
# 0              1    18
# 1              1    17
# 2              1    19
# 3              1    20
# 4              1    19
# ..           ...   ...
# 559            8    17
# 560            8    17
# 561            8    17
# 562            8    16
# 563            8    16
#
# [564 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter(df["Species_num"], df["FPNr"])
ax.set_xlabel("Species_num")
ax.set_ylabel("FPNr")
ax.set_yticks([2 * i for i in range(1, 10)])

# %% [markdown]
# as we can assume from the graph only lizards from the species group number 5 have FPNr < 12 (except for the outlier from the group number 4)

# %%
df.loc[df["FPNr"] < 12]["Species_num"]
# Out:
# 277    5
# 329    5
# 330    5
# 339    5
# 340    5
# 347    5
# 351    5
# 352    5
# 353    5
# 354    5
# 355    5
# 363    5
# 364    4
# 378    5
# 379    5
# 380    5
# 391    5
# 392    5
# 393    5
# 396    5
# 397    5
# 398    5
# 399    5
# 400    5
# 401    5
# Name: Species_num, dtype: int64

# %%
df.loc[df["FPNr"] < 12].loc[df["Species_num"] == 5]
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 277            5        1   M   38   21    6   16    10    25     6  ...
# 329            5        1   M   39   20    6   17    10    21     5  ...
# 330            5        2   F   37   24    7   17     8    18     6  ...
# 339            5        1   M   39   23    4   18    11    23     6  ...
# 340            5        2   F   41   23    5   18     8    25     5  ...
# 347            5        2   F   41   25    7   21     9    22     5  ...
# 351            5        1   M   35   22    7   19    10    21     6  ...
# 352            5        2   F   41   23    6   20     8    24     6  ...
# 353            5        1   M   39   22    6   18    10    23     5  ...
# 354            5        2   F   37   25    5   18     9    20     6  ...
# 355            5        2   F   34   23    5   17     8    22     5  ...
# 363            5        1   M   37   22    6   17     7    22     4  ...
# 378            5        2   F   39   24    5   18     9    21     6  ...
# 379            5        2   F   38   24    5   19     8    23     5  ...
# 380            5        1   M   36   22    6   19    10    24     5  ...
# 391            5        1   M   40   21    7   16    11    22     6  ...
# 392            5        1   M   39   22    5   19    10    23     6  ...
# 393            5        1   M   38   21    5   19     9    20     6  ...
# 396            5        2   F   39   25    9   21     8    16     5  ...
# 397            5        1   M   40   21    7   20    11    16     5  ...
# 398            5        2   F   38   26    7   23     7    16     6  ...
# 399            5        2   F   36   25    6   16     7    14     5  ...
# 400            5        2   F   36   25    7   17     9    16     5  ...
# 401            5        2   F   39   24    8   17     8    16     6  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 277  46.5  22.7  15.7  10.6  7.3  7.7  5.1   8.7  16.5  24.3
# 329  61.0  27.3  18.4  11.9  7.7  7.9  6.1   8.0  17.6  27.2
# 330  50.0  30.2  15.7  10.1  6.7  6.3  5.3   6.4  15.8  22.7
# 339  53.0  28.7  18.7  11.9  7.9  8.0  5.4   8.7  19.5  27.2
# 340  53.0  29.7  16.2  10.4  6.8  6.5  5.3   7.3  17.1  23.9
# 347  51.5  30.8  15.2  10.4  6.9  7.2  5.1   7.3  17.6  24.6
# 351  50.0  23.5  16.5  11.7  7.5  8.1  5.8   9.0  17.3  26.2
# 352  50.0  25.8  17.3  10.6  6.7  7.2  5.4   8.3  18.2  25.8
# 353  45.5  21.3  16.3  10.9  7.2  6.9  5.3   7.9  16.7  25.3
# 354  58.0  33.9  16.6  11.1  7.2  7.4  5.8   7.6  17.2  24.4
# 355  56.5  32.8  17.0  11.1  7.3  7.4  5.6   7.8  17.8  24.7
# 363  43.0  21.6  15.0  10.3  6.8  6.8  5.3   7.4  15.5  24.1
# 378  46.0  25.7  15.1   9.5  6.4  6.6  4.5   6.6  16.0  21.9
# 379  55.0  29.4  17.9  10.7  7.5  6.9  5.1   7.0  17.4  25.1
# 380  46.5  23.5  16.4  10.8  7.2  7.2  5.4   7.6  16.7  24.2
# 391  51.5  26.9  18.2  11.6  7.6  8.0  5.7   8.2  17.9  27.2
# 392  46.0  23.5  17.0  10.8  7.3  7.1  5.1   7.1  16.9  25.2
# 393  38.0  24.1  16.2  11.1  7.4  7.1  5.5   7.4  16.8  25.3
# 396  60.0  33.7  18.0  11.8  7.7  7.0  5.6   9.8  17.0  27.4
# 397  45.5  25.0  16.8  10.5  7.3  6.5  5.1   9.2  17.0  24.8
# 398  51.0  31.0  17.0  10.5  7.0  6.2  4.8   9.0  15.3  24.0
# 399  53.0  31.7  15.4  10.0  6.8  5.9  5.0   8.9  14.5  23.5
# 400  60.0  36.0  16.9  11.4  7.3  6.5  5.2  10.1  18.2  26.0
# 401  62.0  38.0  18.3  11.5  7.4  6.4  5.4  10.6  18.5  28.3
#
# [24 rows x 26 columns]

# %%
df.loc[df["FPNr"] < 12].loc[df["Species_num"] == 4]
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 364            4        1   M   45   25   10   28    10    26     5  ...
#
#       SVL   TRL    HL    PL   ESD    HW   HH    MO   FFL   HFL
# 364  72.0  37.4  26.3  16.8  10.5  11.7  7.4  11.5  25.4  42.1
#
# [1 rows x 26 columns]

# %% [markdown]
# there is only one outlier (group #4 falsely classified as group #5)

# %% [markdown]
# ## Task 2
#
# ### Build a criterion that, with the best possible accuracy, differentiates lizards of species #5 from all other lizards and uses two variables out of the measured morphometric and pholidosis characteristics.
# ### *Hint: one of the methods to find the best pair of predicting variables (predictors) may be exhaustive search over all possible pairs of variables.*

# %%
df
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 0              1        1   M   54   22   10   25    18    27     6  ...
# 1              1        1   M   49   25   12   24    17    25     9  ...
# 2              1        1   M   50   25    9   25    19    27     6  ...
# 3              1        1   M   49   24   11   21    20    25     5  ...
# 4              1        1   M   50   22    9   26    19    25     5  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 559            8        1   M   48   26   10   23    17    16     7  ...
# 560            8        1   M   44   25    9   23    17    14     8  ...
# 561            8        2   F   44   27    9   22    17    18     7  ...
# 562            8        2   F   46   28    9   27    16    16     6  ...
# 563            8        1   M   43   25   10   28    16    18     5  ...
#
#       SVL   TRL    HL    PL   ESD   HW   HH     MO   FFL   HFL
# 0    52.8  25.8  18.0  12.8   6.2  7.9  4.8  10.50  17.2  31.5
# 1    62.0  29.0  21.1  14.0   7.2  9.1  5.1  10.20  20.0  33.0
# 2    60.0  29.5  19.9  13.9   7.5  8.6  4.9  11.00  19.9  34.0
# 3    61.5  29.8  21.5  14.8   7.2  9.8  4.8  11.10  19.5  33.2
# 4    56.0  27.2  19.2  16.0   7.8  8.6  4.9  10.50  19.2  34.2
# ..    ...   ...   ...   ...   ...  ...  ...    ...   ...   ...
# 559  55.2  27.0  18.2  11.5   4.7  7.9  5.1   9.35  17.2  29.0
# 560  58.4  28.0  21.4  13.5   4.4  8.5  5.9  10.55  20.0  30.2
# 561  65.5  38.0  18.5  12.8  18.3  8.0  4.4  11.00  19.0  28.2
# 562  69.0  39.0  19.6  13.6   8.6  8.6  5.0  11.50  18.2  28.7
# 563  56.5  26.8  18.2  12.4   8.0  8.6  5.0  10.80  18.7  28.4
#
# [564 rows x 26 columns]

# %% [markdown]
# as we saw in the previous task criterion **FPNr < 12** is quite good to distinguish species #5 from the other groups except for the #4. let's find the best one to distinguish group #5 from group #4 (to distinguish the outliers from the distinguishing by FPNr)
#
# ## answer: FPNr < 12

# %%
df2 = df.loc[(df["Species_num"] == 4) | (df["Species_num"] == 5)]
df2
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 134            4        2   F   50   28    9   28    19    15     6  ...
# 168            4        1   M   48   24    9   32    20    21     6  ...
# 169            4        2   F   45   25    9   27    18    23     6  ...
# 198            4        1   M   49   25    9   30    19    25     7  ...
# 200            4        2   F   48   26    9   31    18    26     6  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 397            5        1   M   40   21    7   20    11    16     5  ...
# 398            5        2   F   38   26    7   23     7    16     6  ...
# 399            5        2   F   36   25    6   16     7    14     5  ...
# 400            5        2   F   36   25    7   17     9    16     5  ...
# 401            5        2   F   39   24    8   17     8    16     6  ...
#
#       SVL   TRL    HL    PL   ESD    HW   HH    MO   FFL   HFL
# 134  76.0  39.5  21.6  14.5   9.5   9.0  6.3  11.0  23.0  33.0
# 168  70.5  35.0  23.8  16.4  10.8  10.1  6.9  14.3  27.0  38.2
# 169  73.0  37.2  22.9  15.1   9.6   9.3  6.1  11.0  22.6  33.4
# 198  72.5  38.6  23.8  16.9  10.7  10.9  7.6  14.2  24.7  42.9
# 200  69.5  39.4  20.4  13.8   9.1   8.9  6.3   9.5  21.6  34.9
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...
# 397  45.5  25.0  16.8  10.5   7.3   6.5  5.1   9.2  17.0  24.8
# 398  51.0  31.0  17.0  10.5   7.0   6.2  4.8   9.0  15.3  24.0
# 399  53.0  31.7  15.4  10.0   6.8   5.9  5.0   8.9  14.5  23.5
# 400  60.0  36.0  16.9  11.4   7.3   6.5  5.2  10.1  18.2  26.0
# 401  62.0  38.0  18.3  11.5   7.4   6.4  5.4  10.6  18.5  28.3
#
# [117 rows x 26 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter(df2["Species_num"], df2["MBS"])
ax.set_xlabel("Species_num")
ax.set_ylabel("MBS")
ax.set_xticks([4, 5])
ax.set_yticks([40 + i for i in range(5)])

# %% [markdown]
# by plotting MBS and Species_num we can clearly see that MBS > 44 for every lizard from group #4 and MBS < 42 for every lizard from group #5

# %% [markdown]
# thus, we can distinguish group #5 by these criteria:
#
# **FPNr < 12** ans **MBS < 42**
#
# ## answer: FPNr < 12 & MBS < 42

# %%
df.loc[(df["FPNr"] < 12) & (df["MBS"] < 42)]
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 277            5        1   M   38   21    6   16    10    25     6  ...
# 329            5        1   M   39   20    6   17    10    21     5  ...
# 330            5        2   F   37   24    7   17     8    18     6  ...
# 339            5        1   M   39   23    4   18    11    23     6  ...
# 340            5        2   F   41   23    5   18     8    25     5  ...
# 347            5        2   F   41   25    7   21     9    22     5  ...
# 351            5        1   M   35   22    7   19    10    21     6  ...
# 352            5        2   F   41   23    6   20     8    24     6  ...
# 353            5        1   M   39   22    6   18    10    23     5  ...
# 354            5        2   F   37   25    5   18     9    20     6  ...
# 355            5        2   F   34   23    5   17     8    22     5  ...
# 363            5        1   M   37   22    6   17     7    22     4  ...
# 378            5        2   F   39   24    5   18     9    21     6  ...
# 379            5        2   F   38   24    5   19     8    23     5  ...
# 380            5        1   M   36   22    6   19    10    24     5  ...
# 391            5        1   M   40   21    7   16    11    22     6  ...
# 392            5        1   M   39   22    5   19    10    23     6  ...
# 393            5        1   M   38   21    5   19     9    20     6  ...
# 396            5        2   F   39   25    9   21     8    16     5  ...
# 397            5        1   M   40   21    7   20    11    16     5  ...
# 398            5        2   F   38   26    7   23     7    16     6  ...
# 399            5        2   F   36   25    6   16     7    14     5  ...
# 400            5        2   F   36   25    7   17     9    16     5  ...
# 401            5        2   F   39   24    8   17     8    16     6  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 277  46.5  22.7  15.7  10.6  7.3  7.7  5.1   8.7  16.5  24.3
# 329  61.0  27.3  18.4  11.9  7.7  7.9  6.1   8.0  17.6  27.2
# 330  50.0  30.2  15.7  10.1  6.7  6.3  5.3   6.4  15.8  22.7
# 339  53.0  28.7  18.7  11.9  7.9  8.0  5.4   8.7  19.5  27.2
# 340  53.0  29.7  16.2  10.4  6.8  6.5  5.3   7.3  17.1  23.9
# 347  51.5  30.8  15.2  10.4  6.9  7.2  5.1   7.3  17.6  24.6
# 351  50.0  23.5  16.5  11.7  7.5  8.1  5.8   9.0  17.3  26.2
# 352  50.0  25.8  17.3  10.6  6.7  7.2  5.4   8.3  18.2  25.8
# 353  45.5  21.3  16.3  10.9  7.2  6.9  5.3   7.9  16.7  25.3
# 354  58.0  33.9  16.6  11.1  7.2  7.4  5.8   7.6  17.2  24.4
# 355  56.5  32.8  17.0  11.1  7.3  7.4  5.6   7.8  17.8  24.7
# 363  43.0  21.6  15.0  10.3  6.8  6.8  5.3   7.4  15.5  24.1
# 378  46.0  25.7  15.1   9.5  6.4  6.6  4.5   6.6  16.0  21.9
# 379  55.0  29.4  17.9  10.7  7.5  6.9  5.1   7.0  17.4  25.1
# 380  46.5  23.5  16.4  10.8  7.2  7.2  5.4   7.6  16.7  24.2
# 391  51.5  26.9  18.2  11.6  7.6  8.0  5.7   8.2  17.9  27.2
# 392  46.0  23.5  17.0  10.8  7.3  7.1  5.1   7.1  16.9  25.2
# 393  38.0  24.1  16.2  11.1  7.4  7.1  5.5   7.4  16.8  25.3
# 396  60.0  33.7  18.0  11.8  7.7  7.0  5.6   9.8  17.0  27.4
# 397  45.5  25.0  16.8  10.5  7.3  6.5  5.1   9.2  17.0  24.8
# 398  51.0  31.0  17.0  10.5  7.0  6.2  4.8   9.0  15.3  24.0
# 399  53.0  31.7  15.4  10.0  6.8  5.9  5.0   8.9  14.5  23.5
# 400  60.0  36.0  16.9  11.4  7.3  6.5  5.2  10.1  18.2  26.0
# 401  62.0  38.0  18.3  11.5  7.4  6.4  5.4  10.6  18.5  28.3
#
# [24 rows x 26 columns]

# %%
df.loc[(df["FPNr"] < 12) & (df["MBS"] < 42)]["Species_num"].unique()
# Out:
# array([5])

# %% [markdown]
# #### with this metric we can find lizards from group #5 with no outliers

# %% [markdown]
# ## Task 3
# ### Build a criterion that, with the best possible accuracy, predicts lizards’ sex regardless of their biological species on the basis of the morphometric and/or pholidosis characteristics.
# ### *Hint from the biologists: it is expected (but not guaranteed!) that sex is correlated with the ratios of some measured linear sizes; but this does preclude from using other predictors in the criterion.*

# %%
df
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 0              1        1   M   54   22   10   25    18    27     6  ...
# 1              1        1   M   49   25   12   24    17    25     9  ...
# 2              1        1   M   50   25    9   25    19    27     6  ...
# 3              1        1   M   49   24   11   21    20    25     5  ...
# 4              1        1   M   50   22    9   26    19    25     5  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 559            8        1   M   48   26   10   23    17    16     7  ...
# 560            8        1   M   44   25    9   23    17    14     8  ...
# 561            8        2   F   44   27    9   22    17    18     7  ...
# 562            8        2   F   46   28    9   27    16    16     6  ...
# 563            8        1   M   43   25   10   28    16    18     5  ...
#
#       SVL   TRL    HL    PL   ESD   HW   HH     MO   FFL   HFL
# 0    52.8  25.8  18.0  12.8   6.2  7.9  4.8  10.50  17.2  31.5
# 1    62.0  29.0  21.1  14.0   7.2  9.1  5.1  10.20  20.0  33.0
# 2    60.0  29.5  19.9  13.9   7.5  8.6  4.9  11.00  19.9  34.0
# 3    61.5  29.8  21.5  14.8   7.2  9.8  4.8  11.10  19.5  33.2
# 4    56.0  27.2  19.2  16.0   7.8  8.6  4.9  10.50  19.2  34.2
# ..    ...   ...   ...   ...   ...  ...  ...    ...   ...   ...
# 559  55.2  27.0  18.2  11.5   4.7  7.9  5.1   9.35  17.2  29.0
# 560  58.4  28.0  21.4  13.5   4.4  8.5  5.9  10.55  20.0  30.2
# 561  65.5  38.0  18.5  12.8  18.3  8.0  4.4  11.00  19.0  28.2
# 562  69.0  39.0  19.6  13.6   8.6  8.6  5.0  11.50  18.2  28.7
# 563  56.5  26.8  18.2  12.4   8.0  8.6  5.0  10.80  18.7  28.4
#
# [564 rows x 26 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter(df["HL"] / (df["SVL"] + df["TRL"]), df["Sex"])
ax.set_xlabel("HL / (SVL + TRL)")
ax.set_ylabel("Sex")

# %% [markdown]
# as we can see HL / (SVL + TRL) distinguishes female and male lizards.

# %% [markdown]
# ## answer: HL / (SVL + TRL) > 0.225 - male, others - female

# %% [markdown]
# ## Task 4
# ### Not all lizard species in question are found in the same locations. Therefore, in practice, the tasks of distinguishing species from certain subgroups that live together are most often encountered. Build a set of criteria that, with the best possible accuracy, differentiate all species within the following groups:
# ### a. species #6 and #7,
# ### b. species #1 and #2,
# ### c. species #3, #4, and #5.

# %% [markdown]
# ## 4a. species #6 and #7

# %%
df4a = df.loc[(df["Species_num"] == 6) | (df["Species_num"] == 7)]

# %%
df4a  # SMr
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 402            6        2   F   43   27    8   23    16    21     5  ...
# 403            6        2   F   41   26    7   22    14    20     6  ...
# 404            6        2   F   42   24    8   21    14    20     5  ...
# 405            6        2   F   42   26    7   21    17    21     5  ...
# 406            6        2   F   43   26    8   23    16    18     6  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 539            7        2   F   57   28   11   27    17    20     5  ...
# 540            7        2   F   55   28   10   29    19    20     5  ...
# 541            7        2   F   55   28   11   27    21    20     6  ...
# 542            7        2   F   54   28    9   27    19    20     6  ...
# 543            7        2   F   55   26   11   27    17    20     5  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 402  61.6  30.4  18.8  12.8  7.9  7.8  4.5  11.9  20.3  29.9
# 403  58.6  29.8  18.3  13.0  8.6  7.8  4.4  12.0  19.3  29.6
# 404  59.8  30.7  18.4  12.8  8.7  8.7  4.6  10.9  21.5  30.3
# 405  62.8  33.1  19.0  13.1  8.4  7.7  4.2  11.7  21.2  31.0
# 406  61.0  31.8  18.7  12.7  8.7  7.7  5.3  11.1  21.2  29.8
# ..    ...   ...   ...   ...  ...  ...  ...   ...   ...   ...
# 539  57.0  30.0  18.0  11.8  7.4  6.7  4.1   9.7  18.0  27.0
# 540  54.0  28.5  17.9  11.8  7.2  6.5  4.2  10.8  17.7  26.0
# 541  52.3  26.8  17.7  11.5  7.3  6.3  3.8   9.4  18.0  27.7
# 542  52.7  26.3  17.6  11.7  7.5  6.4  3.9   9.3  17.4  28.0
# 543  61.5  31.4  18.6  12.4  7.7  6.7  4.4   9.8  18.5  29.4
#
# [142 rows x 26 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter(df4a["Species_num"], df4a["SCGr"])
ax.set_xlabel("Species_num")
ax.set_ylabel("SCGr")

# %% [markdown]
# according to the graph SCGr range overlaps only at 10 for groups #6 and #7. hence, we can distinguish them simply by checking SCGr
#
# ## if SCGr < 11 it is group #6, else - group #7

# %%
df4a.loc[df["SCGr"] < 11]
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 402            6        2   F   43   27    8   23    16    21     5  ...
# 403            6        2   F   41   26    7   22    14    20     6  ...
# 404            6        2   F   42   24    8   21    14    20     5  ...
# 405            6        2   F   42   26    7   21    17    21     5  ...
# 406            6        2   F   43   26    8   23    16    18     6  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 529            6        2   F   43   27    8   22    17    21     6  ...
# 530            6        2   F   46   26    9   21    16    22     5  ...
# 531            6        2   F   44   27    8   24    16    19     5  ...
# 537            7        2   F   58   28   10   28    20    20     5  ...
# 540            7        2   F   55   28   10   29    19    20     5  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 402  61.6  30.4  18.8  12.8  7.9  7.8  4.5  11.9  20.3  29.9
# 403  58.6  29.8  18.3  13.0  8.6  7.8  4.4  12.0  19.3  29.6
# 404  59.8  30.7  18.4  12.8  8.7  8.7  4.6  10.9  21.5  30.3
# 405  62.8  33.1  19.0  13.1  8.4  7.7  4.2  11.7  21.2  31.0
# 406  61.0  31.8  18.7  12.7  8.7  7.7  5.3  11.1  21.2  29.8
# ..    ...   ...   ...   ...  ...  ...  ...   ...   ...   ...
# 529  49.0  24.0  17.5  11.3  7.0  6.3  4.4   9.0  17.8  26.3
# 530  48.5  23.5  15.8  10.4  6.7  6.4  4.2   7.7  17.8  26.7
# 531  51.0  25.5  17.0  10.9  7.1  6.2  4.1   9.4  17.5  27.4
# 537  59.5  31.0  18.7  12.0  7.4  6.9  4.2  10.6  19.6  29.0
# 540  54.0  28.5  17.9  11.8  7.2  6.5  4.2  10.8  17.7  26.0
#
# [125 rows x 26 columns]

# %%
df4a.loc[df["SCGr"] == 10][df["Species_num"] == 7]
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 429            7        2   F   44   29   12   26    18    20     5  ...
# 431            7        2   F   55   28   10   26    17    21     6  ...
# 517            7        2   F   51   28   10   28    17    19     7  ...
# 537            7        2   F   58   28   10   28    20    20     5  ...
# 540            7        2   F   55   28   10   29    19    20     5  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 429  64.5  31.7  18.9  12.8  8.4  7.2  5.3  11.7  19.4  28.3
# 431  59.3  29.2  18.5  12.0  7.9  6.7  4.9   9.9  20.1  28.6
# 517  55.3  28.2  18.0  12.0  7.4  7.2  4.0   8.5  18.0  28.6
# 537  59.5  31.0  18.7  12.0  7.4  6.9  4.2  10.6  19.6  29.0
# 540  54.0  28.5  17.9  11.8  7.2  6.5  4.2  10.8  17.7  26.0
#
# [5 rows x 26 columns]

# %% [markdown]
# there are five outliers - they will be falsely indicated as group #6 while they are group #7

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter(df4a["Species_num"], df4a["MBS"])
ax.set_xlabel("Species_num")
ax.set_ylabel("MBS")
ax.set_yticks([45 + i for i in range(5)])

# %% [markdown]
# to get rid of the most outliners we will use 2 conditions:
# ## if SCGr < 11 and MBS < 49 it is group #6, else - group #7

# %%
df4a.loc[(df4a["MBS"] < 49) & (df4a["SCGr"] < 11)].loc[df["Species_num"] == 7]
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 429            7        2   F   44   29   12   26    18    20     5  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 429  64.5  31.7  18.9  12.8  8.4  7.2  5.3  11.7  19.4  28.3
#
# [1 rows x 26 columns]

# %% [markdown]
# we still have one outliner

# %%
df_indicated_group6 = df4a.loc[(df4a["MBS"] < 49) & (df4a["SCGr"] < 11)]
df_indicated_group6
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 402            6        2   F   43   27    8   23    16    21     5  ...
# 403            6        2   F   41   26    7   22    14    20     6  ...
# 404            6        2   F   42   24    8   21    14    20     5  ...
# 405            6        2   F   42   26    7   21    17    21     5  ...
# 406            6        2   F   43   26    8   23    16    18     6  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 527            6        2   F   46   28   11   22    17    20     5  ...
# 528            6        2   F   45   27    9   23    17    20     6  ...
# 529            6        2   F   43   27    8   22    17    21     6  ...
# 530            6        2   F   46   26    9   21    16    22     5  ...
# 531            6        2   F   44   27    8   24    16    19     5  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 402  61.6  30.4  18.8  12.8  7.9  7.8  4.5  11.9  20.3  29.9
# 403  58.6  29.8  18.3  13.0  8.6  7.8  4.4  12.0  19.3  29.6
# 404  59.8  30.7  18.4  12.8  8.7  8.7  4.6  10.9  21.5  30.3
# 405  62.8  33.1  19.0  13.1  8.4  7.7  4.2  11.7  21.2  31.0
# 406  61.0  31.8  18.7  12.7  8.7  7.7  5.3  11.1  21.2  29.8
# ..    ...   ...   ...   ...  ...  ...  ...   ...   ...   ...
# 527  55.0  28.7  18.0  11.9  7.6  6.5  4.7  10.3  19.6  28.2
# 528  60.8  31.8  20.0  12.9  8.4  7.4  5.5  11.5  18.6  29.0
# 529  49.0  24.0  17.5  11.3  7.0  6.3  4.4   9.0  17.8  26.3
# 530  48.5  23.5  15.8  10.4  6.7  6.4  4.2   7.7  17.8  26.7
# 531  51.0  25.5  17.0  10.9  7.1  6.2  4.1   9.4  17.5  27.4
#
# [121 rows x 26 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter(df_indicated_group6["Species_num"], df_indicated_group6["HFL"])
ax.set_xlabel("Species_num")
ax.set_ylabel("MBS")

# %% [markdown]
# after checking manually we can conclude that every value for this outlier lies in a range of values from the group #6, so we cannot explicitly get rid of it

# %% [markdown]
# ## answer: if SCGr < 11 and MBS < 49 it is group #6, else - group #7

# %% [markdown]
# # 4b. species #1 and #2,

# %%
df4b = df.loc[(df["Species_num"] == 1) | (df["Species_num"] == 2)]
df4b
# Out:
#      Species_num  Sex_num Sex  MBS  VSN  CSN  GSN  FPNr  SDLr  SCSr  ...  \
# 0              1        1   M   54   22   10   25    18    27     6  ...
# 1              1        1   M   49   25   12   24    17    25     9  ...
# 2              1        1   M   50   25    9   25    19    27     6  ...
# 3              1        1   M   49   24   11   21    20    25     5  ...
# 4              1        1   M   50   22    9   26    19    25     5  ...
# ..           ...      ...  ..  ...  ...  ...  ...   ...   ...   ...  ...
# 124            2        2   F   51   27    8   27    17    25     5  ...
# 125            2        2   F   48   25    9   25    15    21     5  ...
# 126            2        2   F   43   28    9   24    15    23     6  ...
# 127            2        2   F   52   23    7   23    17    25     5  ...
# 128            2        2   F   47   26    9   23    15    21     4  ...
#
#       SVL   TRL    HL    PL  ESD   HW   HH    MO   FFL   HFL
# 0    52.8  25.8  18.0  12.8  6.2  7.9  4.8  10.5  17.2  31.5
# 1    62.0  29.0  21.1  14.0  7.2  9.1  5.1  10.2  20.0  33.0
# 2    60.0  29.5  19.9  13.9  7.5  8.6  4.9  11.0  19.9  34.0
# 3    61.5  29.8  21.5  14.8  7.2  9.8  4.8  11.1  19.5  33.2
# 4    56.0  27.2  19.2  16.0  7.8  8.6  4.9  10.5  19.2  34.2
# ..    ...   ...   ...   ...  ...  ...  ...   ...   ...   ...
# 124  52.9  30.7  16.0  10.6  5.2  6.7  4.7   9.6  14.4  23.7
# 125  58.9  36.1  17.4  11.1  5.5  7.4  4.8   9.4  16.9  24.2
# 126  53.4  33.3  15.6  10.3  5.3  6.1  4.3   9.2  15.3  23.6
# 127  51.5  31.2  16.0  10.6  5.2  6.6  4.5   9.5  15.8  23.3
# 128  56.9  34.2  18.0  11.1  5.3  7.7  4.3   9.4  15.5  24.6
#
# [129 rows x 26 columns]

# %%
df4b.columns
# Out:
# Index(['Species_num', 'Sex_num', 'Sex', 'MBS', 'VSN', 'CSN', 'GSN', 'FPNr',
#        'SDLr', 'SCSr', 'SCGr', 'SMr', 'MTr', 'PA', 'PTMr', 'aNDSr', 'SVL',
#        'TRL', 'HL', 'PL', 'ESD', 'HW', 'HH', 'MO', 'FFL', 'HFL'],
#       dtype='str')

# %%
for col in df4b.columns:
    plt.figure()
    fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
    ax.scatter(df4b["Species_num"], df4b[col])
    plt.savefig(f"figures_{col}")

# %% [markdown]
# by analyzing these graphs we can conclude that every one of the ranges for every column intersect for these 2 groups
